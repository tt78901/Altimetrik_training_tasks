# %%
import pandas as pd

# %%
df1=pd.Series([10,20,30,50,60])
df2=pd.Series([100,150,130,150,100])

df=pd.DataFrame({'col1':df1,'col2':df2})
df
# Out:
#    col1  col2
# 0    10   100
# 1    20   150
# 2    30   130
# 3    50   150
# 4    60   100

# %%
print(df2[0])
# Out:
# 100

# %%
df=pd.Series([1,2,3,5],index=['a','b','c','d'])
print(df['a'])
# Out:
# 1

# %%
dict1={
    "Name":["Tarun","Mohan","Devi","Akhil","Asan"],
    "Age":[21,30,23,25,23],
    "Department":["IT","HR","Finance","Market Research","Trading"],
    "Salary" :[10000,200000,300000,400000,5000000]
}

DF=pd.DataFrame(dict1)
DF
# Out:
#     Name  Age       Department   Salary
# 0  Tarun   21               IT    10000
# 1  Mohan   30               HR   200000
# 2   Devi   23          Finance   300000
# 3  Akhil   25  Market Research   400000
# 4   Asan   23          Trading  5000000

# %%
DF.loc[DF['Name'] == 'Tarun', 'Age'] # Accesses the 'Age' value for the row where the 'Name' is 'Tarun'
# Out:
# 0    21
# Name: Age, dtype: int64

# %%
DF[["Name","Age","Department"]]
# Out:
#     Name  Age       Department
# 0  Tarun   21               IT
# 1  Mohan   30               HR
# 2   Devi   23          Finance
# 3  Akhil   25  Market Research
# 4   Asan   23          Trading

# %%
DF.iloc[0:]
# Out:
#     Name  Age       Department   Salary
# 0  Tarun   21               IT    10000
# 1  Mohan   30               HR   200000
# 2   Devi   23          Finance   300000
# 3  Akhil   25  Market Research   400000
# 4   Asan   23          Trading  5000000

# %%
print(DF[DF["Age"]>=21])
print("\n")
print(DF[DF["Name"]=="Asan"])
# Out:
#     Name  Age       Department   Salary
# 0  Tarun   21               IT    10000
# 1  Mohan   30               HR   200000
# 2   Devi   23          Finance   300000
# 3  Akhil   25  Market Research   400000
# 4   Asan   23          Trading  5000000
#
#
#    Name  Age Department   Salary
# 4  Asan   23    Trading  5000000

# %%
DF["Bonus"]=DF["Salary"]+5000
DF["Income Tax"]=DF["Salary"]*0.03
DF
# Out:
#     Name  Age       Department   Salary    Bonus  Income Tax
# 0  Tarun   21               IT    10000    15000       300.0
# 1  Mohan   30               HR   200000   205000      6000.0
# 2   Devi   23          Finance   300000   305000      9000.0
# 3  Akhil   25  Market Research   400000   405000     12000.0
# 4   Asan   23          Trading  5000000  5005000    150000.0

# %%
DF["Salary"].describe()
# Out:
# count    5.000000e+00
# mean     1.182000e+06
# std      2.139187e+06
# min      1.000000e+04
# 25%      2.000000e+05
# 50%      3.000000e+05
# 75%      4.000000e+05
# max      5.000000e+06
# Name: Salary, dtype: float64

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         5 non-null      int64
#  2   Department  5 non-null      object
#  3   Salary      5 non-null      int64
#  4   Bonus       5 non-null      int64
#  5   Income Tax  5 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 372.0+ bytes

# %%
DF.isnull().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# Bonus         0
# Income Tax    0
# dtype: int64

# %%
df4=pd.read_csv('/content/employee.csv')
df4
# Out:
#    EmpID    Name  Age Department  Salary
# 0    101    John   28         IT   50000
# 1    102    Emma   34         HR   60000
# 2    103    Ryan   29    Finance   55000
# 3    104  Sophia   25  Marketing   52000

# %%
print(df.isnull().sum())
# Out:
# 0

# %%
print(df.info())
# Out:
# <class 'pandas.core.series.Series'>
# Index: 4 entries, a to d
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      int64
# dtypes: int64(1)
# memory usage: 236.0+ bytes
# None

# %%
df.describe()
# Out:
# count    4.000000
# mean     2.750000
# std      1.707825
# min      1.000000
# 25%      1.750000
# 50%      2.500000
# 75%      3.500000
# max      5.000000
# dtype: float64

# %%
# Assuming df4 contains the desired data with the 'Age' column
print(df4[df4["Age"]>=28])
# Out:
#    EmpID  Name  Age Department  Salary
# 0    101  John   28         IT   50000
# 1    102  Emma   34         HR   60000
# 2    103  Ryan   29    Finance   55000
