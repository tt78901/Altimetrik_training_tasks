# %%
import pandas as pd

# %%
df=pd.Series([65, 70, 85, 90, 55])

# %%
#Create a Pandas Series from a list of student marks [65, 70, 85, 90, 55]
df2=pd.Series([65, 70, 85, 90, 55])
df1=pd.Series(["Tarun","Devi","Akhil","Asan","Dinesh"])
df3=pd.DataFrame({'Name':df1,'Marks':df2})

# %%
df3
# Out:
#      Name  Marks
# 0   Tarun     65
# 1    Devi     70
# 2   Akhil     85
# 3    Asan     90
# 4  Dinesh     55

# %%
#Calculate the average marks.
print(df3["Marks"].mean())
# Out:
# 73.0

# %%
#Identify students who scored more than 75.
df3[df3["Marks"]>75]
# Out:
#     Name  Marks
# 2  Akhil     85
# 3   Asan     90

# %%
#Create a DataFrame for 5 employees with columns: ['EmpID', 'Name', 'Department', 'Salary'].
dict1={
    "EmpID":[111,112,113,114,115],
    "Name":["Tarun","Akhil","Devi","Asan","Dinesh"],
    "Department":["IT","HR","Finance","Market Research","Trading"],
    "Salary" :[10000,200000,300000,400000,5000000]}

df4=pd.DataFrame(dict1)

# %%
#Add a new column called Bonus as 10% of the Salary.
df4["Bonus"]=df4["Salary"]*0.01
df4["Bonus"]
# Out:
# 0      100.0
# 1     2000.0
# 2     3000.0
# 3     4000.0
# 4    50000.0
# Name: Bonus, dtype: float64

# %%
#Display the data types of all columns.
print(df4.dtypes)
# Out:
# EmpID           int64
# Name           object
# Department     object
# Salary          int64
# Bonus         float64
# dtype: object
